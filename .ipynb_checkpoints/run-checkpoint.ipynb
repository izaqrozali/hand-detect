# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data

import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms

import time
import shutil

from torchsample.modules import ModuleTrainer
import torchsample

# %%
base_path = "data"
train_path = base_path + "/train"
valid_path = base_path + "/valid"

# %%
mean_val, std_val = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]
train_tmft =  transforms.Compose([
    transforms.RandomRotation(30),
    transforms.CenterCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_val,std_val)
])

valid_tmft =  transforms.Compose([
    transforms.Resize(224),
#     transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean_val,std_val)
])

# TODO: Load the datasets with ImageFolder
trainset = torchvision.datasets.ImageFolder(train_path, transform=train_tmft)
validset = torchvision.datasets.ImageFolder(valid_path, transform=valid_tmft)


BSIZE = 20
train_loader = torch.utils.data.DataLoader(trainset, batch_size=BSIZE, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(validset, batch_size=BSIZE, shuffle=True, num_workers=0)

CLAZZ = len(trainset.classes)
CLAZZ
# Out:
# 7

# %%
dataiter = iter(valid_loader)
images, labels = dataiter.next()

# %%
img = images[2].permute(1,2,0).numpy()
# img = np.clip(img, 0, 1)
plt.imshow(img, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        
        
def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)
        
        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %%
def hand_squeezenet(pretrained=True, n_class=1000):
    net=torchvision.models.squeezenet1_1(pretrained=pretrained)
    net.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Conv2d(512, n_class, kernel_size=1, stride=1),
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=13, stride=1, padding=0)
        )
    net.forward = lambda x: net.classifier(net.features(x)).view(x.size(0), n_class)
    return net



# model=hand_squeezenet(pretrained=True, n_class=7)
# x=torch.randn(2,3,224,224)
# model(x)

# %%
from torchtools.trainer import Trainer
from torchtools.meters import LossMeter, AccuracyMeter
from torchtools.callbacks import (StepLR, ReduceLROnPlateau, TensorBoardLogger, CSVLogger)


model = hand_squeezenet(pretrained=True, n_class=7)
optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
criterion = nn.CrossEntropyLoss()

trainer = Trainer(model, train_loader, criterion, optimizer, valid_loader)


loss = LossMeter('loss')
val_loss = LossMeter('val_loss')
acc = AccuracyMeter('acc')
val_acc = AccuracyMeter('val_acc')
scheduler = StepLR(optimizer, 1, gamma=0.95)
reduce_lr = ReduceLROnPlateau(optimizer, 'val_loss', factor=0.3, patience=3)
logger = TensorBoardLogger()
csv_logger = CSVLogger(keys=['epochs', 'loss', 'acc', 'val_loss', 'val_acc'])

trainer.register_hooks([loss, val_loss, acc, val_acc, scheduler, reduce_lr, logger, csv_logger])

output = trainer.train(1)
# Out:
# Train:   0%|          | 0/1 [00:00<?, ?epoch/s]
#   0%|          | 0/28 [00:00<?, ? batches/s]
# Epoch 0:   0%|          | 0/28 [00:00<?, ? batches/s]
# Epoch 0:   0%|          | 0/28 [00:01<?, ? batches/s, iters=1, loss=2.21]
# Epoch 0:   4%|▎         | 1/28 [00:02<01:05,  2.44s/ batches, iters=1, loss=2.21]
# Epoch 0:   4%|▎         | 1/28 [00:03<01:05,  2.44s/ batches, iters=2, loss=1.97]
# Epoch 0:   7%|▋         | 2/28 [00:03<00:55,  2.12s/ batches, iters=2, loss=1.97]
# Epoch 0:   7%|▋         | 2/28 [00:04<00:55,  2.12s/ batches, iters=3, loss=1.73]
# Epoch 0:  11%|█         | 3/28 [00:05<00:48,  1.94s/ batches, iters=3, loss=1.73]
# Epoch 0:  11%|█         | 3/28 [00:06<00:48,  1.94s/ batches, iters=4, loss=1.95]
# Epoch 0:  14%|█▍        | 4/28 [00:06<00:42,  1.78s/ batches, iters=4, loss=1.95]
# Epoch 0:  14%|█▍        | 4/28 [00:07<00:42,  1.78s/ batches, iters=5, loss=2.04]
# Epoch 0:  18%|█▊        | 5/28 [00:08<00:38,  1.68s/ batches, iters=5, loss=2.04]
# Epoch 0:  18%|█▊        | 5/28 [00:09<00:38,  1.68s/ batches, iters=6, loss=1.69]
# Epoch 0:  21%|██▏       | 6/28 [00:09<00:35,  1.61s/ batches, iters=6, loss=1.69]
# Epoch 0:  21%|██▏       | 6/28 [00:10<00:35,  1.61s/ batches, iters=7, loss=1.66]
# Epoch 0:  25%|██▌       | 7/28 [00:11<00:32,  1.56s/ batches, iters=7, loss=1.66]
# Epoch 0:  25%|██▌       | 7/28 [00:11<00:32,  1.56s/ batches, iters=8, loss=1.71]
# Epoch 0:  29%|██▊       | 8/28 [00:12<00:30,  1.52s/ batches, iters=8, loss=1.71]
# Epoch 0:  29%|██▊       | 8/28 [00:13<00:30,  1.52s/ batches, iters=9, loss=1.73]
# Epoch 0:  32%|███▏      | 9/28 [00:13<00:28,  1.50s/ batches, iters=9, loss=1.73]
# Epoch 0:  32%|███▏      | 9/28 [00:14<00:28,  1.50s/ batches, iters=10, loss=1.84]
# Epoch 0:  36%|███▌      | 10/28 [00:15<00:26,  1.49s/ batches, iters=10, loss=1.84]
# Epoch 0:  36%|███▌      | 10/28 [00:16<00:26,  1.49s/ batches, iters=11, loss=1.26]
# Epoch 0:  39%|███▉      | 11/28 [00:16<00:25,  1.47s/ batches, iters=11, loss=1.26]
# Epoch 0:  39%|███▉      | 11/28 [00:17<00:25,  1.47s/ batches, iters=12, loss=1.57]
# Epoch 0:  43%|████▎     | 12/28 [00:18<00:23,  1.48s/ batches, iters=12, loss=1.57]
# Epoch 0:  43%|████▎     | 12/28 [00:19<00:23,  1.48s/ batches, iters=13, loss=1.77]
# Epoch 0:  46%|████▋     | 13/28 [00:19<00:22,  1.49s/ batches, iters=13, loss=1.77]
# Epoch 0:  46%|████▋     | 13/28 [00:20<00:22,  1.49s/ batches, iters=14, loss=1.37]
# Epoch 0:  50%|█████     | 14/28 [00:21<00:20,  1.47s/ batches, iters=14, loss=1.37]
# Epoch 0:  50%|█████     | 14/28 [00:22<00:20,  1.47s/ batches, iters=15, loss=1.61]
# Epoch 0:  54%|█████▎    | 15/28 [00:22<00:19,  1.47s/ batches, iters=15, loss=1.61]
# Epoch 0:  54%|█████▎    | 15/28 [00:23<00:19,  1.47s/ batches, iters=16, loss=1.55]
# Epoch 0:  57%|█████▋    | 16/28 [00:24<00:17,  1.47s/ batches, iters=16, loss=1.55]
# Epoch 0:  57%|█████▋    | 16/28 [00:25<00:17,  1.47s/ batches, iters=17, loss=1.88]
# Epoch 0:  61%|██████    | 17/28 [00:26<00:17,  1.59s/ batches, iters=17, loss=1.88]
# Epoch 0:  61%|██████    | 17/28 [00:26<00:17,  1.59s/ batches, iters=18, loss=1.35]
# Epoch 0:  64%|██████▍   | 18/28 [00:27<00:15,  1.56s/ batches, iters=18, loss=1.35]
# Epoch 0:  64%|██████▍   | 18/28 [00:28<00:15,  1.56s/ batches, iters=19, loss=1.27]
# Epoch 0:  68%|██████▊   | 19/28 [00:29<00:14,  1.56s/ batches, iters=19, loss=1.27]
# Epoch 0:  68%|██████▊   | 19/28 [00:29<00:14,  1.56s/ batches, iters=20, loss=1.19]
# Epoch 0:  71%|███████▏  | 20/28 [00:30<00:12,  1.54s/ batches, iters=20, loss=1.19]
# Epoch 0:  71%|███████▏  | 20/28 [00:31<00:12,  1.54s/ batches, iters=21, loss=1.13]
# Epoch 0:  75%|███████▌  | 21/28 [00:32<00:11,  1.57s/ batches, iters=21, loss=1.13]
# Epoch 0:  75%|███████▌  | 21/28 [00:33<00:11,  1.57s/ batches, iters=22, loss=1.08]
# Epoch 0:  79%|███████▊  | 22/28 [00:33<00:09,  1.53s/ batches, iters=22, loss=1.08]
# Epoch 0:  79%|███████▊  | 22/28 [00:34<00:09,  1.53s/ batches, iters=23, loss=0.93]
# Epoch 0:  82%|████████▏ | 23/28 [00:35<00:07,  1.52s/ batches, iters=23, loss=0.93]
# Epoch 0:  82%|████████▏ | 23/28 [00:36<00:07,  1.52s/ batches, iters=24, loss=0.784]
# Epoch 0:  86%|████████▌ | 24/28 [00:36<00:05,  1.49s/ batches, iters=24, loss=0.784]
# Epoch 0:  86%|████████▌ | 24/28 [00:37<00:05,  1.49s/ batches, iters=25, loss=0.951]
# Epoch 0:  89%|████████▉ | 25/28 [00:38<00:04,  1.47s/ batches, iters=25, loss=0.951]
# Epoch 0:  89%|████████▉ | 25/28 [00:38<00:04,  1.47s/ batches, iters=26, loss=1.26]
# Epoch 0:  93%|█████████▎| 26/28 [00:39<00:02,  1.46s/ batches, iters=26, loss=1.26]
# Epoch 0:  93%|█████████▎| 26/28 [00:40<00:02,  1.46s/ batches, iters=27, loss=1.24]
# Epoch 0:  96%|█████████▋| 27/28 [00:41<00:01,  1.54s/ batches, iters=27, loss=1.24]
# Epoch 0:  96%|█████████▋| 27/28 [00:42<00:01,  1.54s/ batches, iters=28, loss=0.482]
# Epoch 0: 100%|██████████| 28/28 [00:42<00:00,  1.52s/ batches, iters=28, loss=0.482]
#
#   0%|          | 0/7 [00:00<?, ? batches/s]
# Validate:   0%|          | 0/7 [00:00<?, ? batches/s]
# Validate:   0%|          | 0/7 [00:00<?, ? batches/s, loss=2.07]
# Validate:  14%|█▍        | 1/7 [00:00<00:05,  1.14 batches/s, loss=2.07]
# Validate:  14%|█▍        | 1/7 [00:01<00:05,  1.14 batches/s, loss=2.08]
# Validate:  29%|██▊       | 2/7 [00:01<00:04,  1.15 batches/s, loss=2.08]
# Validate:  29%|██▊       | 2/7 [00:02<00:04,  1.15 batches/s, loss=1.67]
# Validate:  43%|████▎     | 3/7 [00:02<00:03,  1.14 batches/s, loss=1.67]
# Validate:  43%|████▎     | 3/7 [00:03<00:03,  1.14 batches/s, loss=1.07]
# Validate:  57%|█████▋    | 4/7 [00:03<00:02,  1.14 batches/s, loss=1.07]
# Validate:  57%|█████▋    | 4/7 [00:04<00:02,  1.14 batches/s, loss=1.41]
# Validate:  71%|███████▏  | 5/7 [00:04<00:01,  1.11 batches/s, loss=1.41]
# Validate:  71%|███████▏  | 5/7 [00:05<00:01,  1.11 batches/s, loss=0.866]
# Validate:  86%|████████▌ | 6/7 [00:05<00:00,  1.10 batches/s, loss=0.866]
# Validate:  86%|████████▌ | 6/7 [00:06<00:00,  1.10 batches/s, loss=1.35]
# Validate: 100%|██████████| 7/7 [00:06<00:00,  1.05 batches/s, loss=1.35]
# Train: 100%|██████████| 1/1 [00:49<00:00, 49.27s/epoch]

# %%
output.keys()
# Out:
# dict_keys(['model', 'arch', 'max_epoch', 'epochs', 'iters', 'optimizer', 'mode', 'meters', 'input', 'target', 'loss', 'output'])

# %%
output['output']
# Out:
# tensor([[ 2.2040,  5.2670,  9.1105,  5.7098,  2.6074,  4.7027,  1.2010],
#         [ 4.0911,  2.4335,  2.7915,  8.2978,  6.6609,  5.5797,  1.8803],
#         [ 4.2836,  5.0266,  6.9239,  6.3112,  2.5507,  4.8545,  1.5076],
#         [ 3.1427,  5.8728,  4.7386,  5.2419,  2.6438,  2.7889,  2.8660],
#         [ 3.6819,  1.1776,  3.0192,  5.3216,  5.7579,  3.6985,  1.9637],
#         [ 4.2931,  1.9895,  2.4564,  1.2342,  2.8321,  2.2365,  8.8446],
#         [ 0.4081,  0.4446,  0.4032,  0.2352,  0.8230,  0.1153,  1.5457],
#         [ 2.8451,  4.0817,  2.8886,  6.4848,  8.0285,  6.6433,  1.5431],
#         [10.6287,  3.6674,  3.3764,  6.0440,  2.4095,  0.9935,  1.2323],
#         [ 4.0031,  2.2713,  4.5100,  7.3191,  3.2415,  4.8737,  0.9834],
#         [ 2.7124,  4.4663,  3.8191,  8.4981,  6.0107,  6.0843,  1.2341],
#         [ 2.0742,  1.3342,  4.7425,  6.5920,  6.8668,  6.3282,  1.4180],
#         [ 9.4299,  3.8385,  2.7048,  5.3714,  2.4219,  0.9783,  0.8895],
#         [ 9.6537,  3.7948,  3.0983,  6.3315,  2.5111,  1.2591,  1.7669],
#         [ 6.2247,  5.2950,  5.7776,  5.8560,  3.7378,  1.7225,  1.9810],
#         [ 0.9160,  1.0142,  4.3211,  4.6120,  5.3874,  8.1261,  1.0198],
#         [ 3.3716,  2.2560,  3.2515,  7.7215,  6.9127,  5.9005,  1.0884],
#         [ 3.9173,  6.4441, 12.9409,  7.2570,  4.0540,  6.9422,  3.3540],
#         [ 3.0937,  1.8231,  2.6147,  5.8105,  3.1699,  5.9270,  1.5589],
#         [ 4.6604,  3.4066,  4.6096,  6.9921,  4.0855,  6.0992,  0.9895]],
#        grad_fn=<ViewBackward>)
